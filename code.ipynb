# %%
    import json
    import time
    sale=''
    fd=open('data.json','r')
    pro=fd.read()
    fd.close()

    product=json.loads(pro)


    print('-'*60) 
    print('\t\t\tMenu')
    print('-'*60)
    for key in product.keys():
        print(key, ':', product[key]['Name'], '|', product[key]['price'], '|', product[key]['Qty'], '|', '\n')
    print('-'*60)
    Name=    str(input('Enter Your Name          : '))
    Email=   str(input('Enter your email id      : '))
    ph_no=   str(input('Enter your phone no      : '))
    pro_id=  str(input('Enter a product id       : '))
    pro_qty= int(input('Enter a Quantity         : '))
    if(product[pro_id]['Qty']>=pro_qty):
        product[pro_id]["Qty"] = product[pro_id]["Qty"] - pro_qty

        print('-'*60)
        print('                 A1 Shop')
        print('-'*60)

        print('Name    : ' ,product[pro_id]['Name'])
        print('Price   : ',product[pro_id]['price'])
        print('Qty     : ' ,pro_qty)
        print('-'*60)
        tot=pro_qty*product[pro_id]['price']
        print('total   :',tot)
        print('-'*60)
        CGST=5/100*tot
        SGST=5/100*tot
        if(tot>10000):
            d=20/100*(tot+ CGST+SGST)
            print('CGST 5%     : ',CGST)
            print('SGST 5%     : ',SGST)
            print('Discount 20%: ',d)
            print('-'*60)
            s_total=(tot+ CGST+SGST)-d
            print('Subtotal    : ',s_total)
        else:
            print('CGST 5% : ',CGST)
            print('SGST 5% : ',SGST)
            print('-'*60)
            s_total=tot+ CGST+SGST
            print('Subtotal: ',s_total)
        print('-'*60)
        sale=Name+','+ph_no+','+Email+','+pro_id+','+product[pro_id]['Name']+','+str(pro_qty)+','+str(pro_qty*product[pro_id]['price'])+time.ctime()+'\n'
    else:
        print('sorry we have not enough quantity!')
        print('we have only',product[pro_id]['Qty'],'this much quantity')
        use_want=input('You want to purchase than press Y/y if no than press N/n')
        if(use_want=='Y'or use_want=='y'):
            print('-'*60)
            print('                  A1 Shop')
            print('-'*60)

            print('Name    : ' ,product[pro_id]['Name'])
            print('Price   : ',product[pro_id]['price'])
            print('Qty     : ' ,product[pro_id]['Qty'])
            print('-'*60)
            tot=product[pro_id]['Qty']*product[pro_id]['price']
            print('Total   :',tot)
            print('-'*60)
            CGST=5/100*tot
            SGST=5/100*tot
            if(tot>10000):
                d=20/100*(tot+ CGST+SGST)
                print('CGST 5%     : ',CGST)
                print('SGST 5%     : ',SGST)
                print('Discount 20%: ',d)
                print('-'*60)
                s_total=(tot+ CGST+SGST)-d
                print('Subtotal    : ',s_total)
            else:
                print('CGST 5% : ',CGST)
                print('SGST 5% : ',SGST)
                print('-'*60)
                s_total=tot+ CGST+SGST
                print('Subtotal: ',s_total)
            sale=Name+','+ph_no+','+Email+','+pro_id+','+product[pro_id]['Name']+','+str(pro_qty)+','+str(pro_qty*product[pro_id]['price'])+','+time.ctime()+'\n'
            product[pro_id]["Qty"] = 0
        else:
            print('thanks for visiting us')
    js=json.dumps(product)
    fd=open('data.json','w')
    fd.write(js)
    fd.close()
    
    fd=open('sales.txt','a')
    fd.write(sale)
    fd.close()
    print('\t\tThank you visit again')
# Out:
# ------------------------------------------------------------
# 			Menu
# ------------------------------------------------------------
# 101 : dawat rice 70car | 650 | 0 |
#
# 102 : Sugar | 100 | 260 |
#
# 103 : Dal | 200 | 0 |
#
# 104 : Masoor | 150 | 480 |
#
# 105 : Gehu | 500 | 980 |
#
# ------------------------------------------------------------
# Enter Your Name          : sumit
# Enter your email id      : bshshjfsd
# Enter your phone no      : 6786217424
# Enter a product id       : 104
# Enter a Quantity         : 20
# ------------------------------------------------------------
#                  Kalamkar Agency
# ------------------------------------------------------------
# Name    :  Masoor
# Price   :  150
# Qty     :  20
# ------------------------------------------------------------
# total   : 3000
# ------------------------------------------------------------
# CGST 5% :  150.0
# SGST 5% :  150.0
# ------------------------------------------------------------
# ...

# %%
s=10
v=20
a=s+v
print(a)
# Out:
# 30

# %%
json
